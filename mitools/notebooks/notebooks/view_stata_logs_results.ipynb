# %%
import pandas as pd
from mitools import regressions as reg
import os
from pathlib import Path
from IPython.display import display_markdown
import openpyxl

# %%
def auto_adjust_columns_width(sheet):
    for column in sheet.columns:
        max_length = 0
        column = [cell for cell in column if cell.value]  # Filter out None values
        for cell in column:
            try:
                if len(str(cell.value)) > max_length:
                    max_length = len(str(cell.value))
            except:
                pass
        adjusted_width = (max_length + 1)  # Adding a little extra width
        sheet.column_dimensions[openpyxl.utils.get_column_letter(column[0].column)].width = adjusted_width

# %%
DB_PATH = Path('/Users/sebastian/Desktop/MontagnaInc/Research/DataWork/datamanagement')
OLS_DF_PATH = DB_PATH / 'OLS_Results.xlsx'
CSARDL_DF_PATH = DB_PATH / 'CSARDL_Results.xlsx'
XTREG_DF_PATH = DB_PATH / 'XTREG_Results.xlsx'

# %%
path = DB_PATH / 'fe_2024_01_10.xlsx'
print(path)
# Out:
# /Users/sebastian/Desktop/MontagnaInc/Research/DataWork/datamanagement/fe_2024_01_10.xlsx

# %%
dataframe = pd.read_excel(path, index_col=0).dropna()
dataframe
# Out:
#                                                  Dep Var  \
# 0                    CO2 emissions (kg per PPP $ of GDP)
# 1                    CO2 emissions (kg per PPP $ of GDP)
# 2                    CO2 emissions (kg per PPP $ of GDP)
# 3                    CO2 emissions (kg per PPP $ of GDP)
# 4                    CO2 emissions (kg per PPP $ of GDP)
# ...                                                  ...
# 62241  Total greenhouse gas emissions (kt of CO2 equi...
# 62242  Total greenhouse gas emissions (kt of CO2 equi...
# 62243  Total greenhouse gas emissions (kt of CO2 equi...
# 62244  Total greenhouse gas emissions (kt of CO2 equi...
# 62245  Total greenhouse gas emissions (kt of CO2 equi...
#
#                                            Variable         Indep Var  \
# 0                                  Agriculture SECI  Agriculture SECI
# 1                                      Fishing SECI  Agriculture SECI
# 2                             Food & Beverages SECI  Agriculture SECI
# 3                                    Machinery SECI  Agriculture SECI
# 4                               Metal Products SECI  Agriculture SECI
# ...                                             ...               ...
# 62241                             Total Patents_log   Agriculture SCI
# 62242                     RenewETotalpctESupply_log   Agriculture SCI
# 62243                  EnergySupplyTotalMillToe_log   Agriculture SCI
# 62244  Urban population (% of total population)_log   Agriculture SCI
# 62245                                         _cons   Agriculture SCI
#
#                Group      Id   Type             Result
# 0      All countries  7407d8  xtreg     -0.908 (0.721)
# 1      All countries  7407d8  xtreg  -5.252 (0.002)***
# 2      All countries  7407d8  xtreg   6.972 (0.009)***
# 3      All countries  7407d8  xtreg      1.672 (0.368)
# 4      All countries  7407d8  xtreg     4.566 (0.0)***
# ...              ...     ...    ...                ...
# 62241     Low income  254802  xtreg      -0.011 (0.39)
# 62242     Low income  254802  xtreg   -1.068 (0.011)**
# 62243     Low income  254802  xtreg  -0.206 (0.009)***
# 62244     Low income  254802  xtreg    0.675 (0.024)**
# 62245     Low income  254802  xtreg       3.69 (0.367)
#
# [60667 rows x 7 columns]

# %%
type = os.path.basename(path).split('_')[0]
if type == 'csardl':
    dataframe = dataframe.set_index(['Id', 'Type', 'Group', 'Dep Var', 'Indep Var', 'Lag', 'Time Span', 'Variable'])
elif type == 'ols':
    dataframe = dataframe.set_index(['Id', 'Type', 'Group', 'Dep Var', 'Indep Var', 'Variable'])
elif type in ['fe', 'fe-te']:
    dataframe = dataframe.set_index(['Id', 'Type', 'Group', 'Dep Var', 'Indep Var', 'Variable'])

# %%
dataframe
# Out:
# Index(['Agriculture SECI', 'Fishing SECI', 'Food & Beverages SECI',
#        'Machinery SECI', 'Metal Products SECI', 'Mining & Quarrying SECI',
#        'Other Manufacturing SECI', 'Petroleum, Chemicals & Non-Metals SECI',
#        'Textiles & Wearing Apparel SECI', 'Transport Equipment SECI',
#        'Wood & Paper SECI', '_cons', 'Population, total',
#        'Population growth (annual %)', 'GDP per capita (current US$)',
#        'GDP per capita (current US$)_square', 'Total Patents',
#        'Renewable energy consumption (% of total final energy consumption)',
#        'Urban population (% of total population)',
#        'Agriculture, forestry, and fishing, value added (% of GDP)',
#        'RenewETotalpctESupply', 'EnergySupplyTotalMillToe',
#        'Total natural resources rents (% of GDP)', 'Energy Productivity',
#        'Population, total_log', 'GDP per capita (current US$)_log',
#        'Total Patents_log',
#        'Renewable energy consumption (% of total final energy consumption)_log',
#        'Urban population (% of total population)_log',
#        'Agriculture, forestry, and fishing, value added (% of GDP)_log',
#        'RenewETotalpctESupply_log', 'EnergySupplyTotalMillToe_log',
#        'Total natural resources rents (% of GDP)_log',
#        'Energy Productivity_log', 'Agriculture SCI', 'Fishing SCI',
#        'Food & Beverages SCI', 'Machinery SCI', 'Metal Products SCI',
#        'Mining & Quarrying SCI', 'Other Manufacturing SCI',
#        'Petroleum, Chemicals & Non-Metals SCI',
#        'Textiles & Wearing Apparel SCI', 'Transport Equipment SCI',
#        'Wood & Paper SCI'],
#       dtype='object', name='Variable')

# %% [markdown]
# ## Regressions Results

# %%
import mitools as mt
mt.iprint([c for c in dataframe.index.get_level_values('Dep Var').unique() if c.find('_log') == -1], c='green')
# Out:
# CO2 emissions (kg per PPP $ of GDP)
# CO2 emissions (metric tons per capita)
# CO2 emissions (kt)
# Emissions Intensity
# Energy Intensity
# Energy Productivity
# EnergySupplyTotalMillToe
# GDP (current US$)
# GDP, PPP (current international $)_in_3_years
# GDP, PPP (current international $)_in_5_years
# GDP growth (annual %)
# GDP growth (annual %)_in_3_years
# GDP growth (annual %)_in_5_years
# GDP per capita (current US$)
# GDP, PPP (current international $)
# Greenhouse gas emissions from electricity and heat
# Greenhouse gas emissions from agriculture
# Greenhouse gas emissions from industry
# Greenhouse gas emissions from land use change and forestry
# Greenhouse gas emissions from manufacturing and construction
# Greenhouse gas emissions from other fuel combustion
# Greenhouse gas emissions from transport
# GNI (current US$)
# GNI, PPP (current international $)
# RenewETotalpctESupply
# Total Eco Footprint
# Total greenhouse gas emissions (kt of CO2 equivalent)

# %%
dfs_to_export = {}

# %%
eci_col = 'PSEV'#'SSCI'

# %%
columns = ['Group']
sub_columns_filters = {
    'Group': []
}
sub_index_filters = {
    'Indep Var': [],
    'Id': []
}
indicators = [
'Total greenhouse gas emissions (kt of CO2 equivalent)_log',
]

view = reg.df_view(dataframe, indicators, columns, sub_columns_filters, sub_index_filters, f' {eci_col}', 'Group', 'Id')
dfs_to_export[indicators[0]] = view
print(f'{indicators[0]}')
display(view)
# Out:
# Energy Intensity_log
# <style type="text/css">
# #T_eef69 tbody tr th.level-1 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_eef69 tbody tr th.level0 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_eef69 tbody tr th.level1 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_eef69 tbody tr th.level2 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_eef69 tbody tr th.level3 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_eef69 tbody tr th.level4 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_eef69 tbody tr th.level5 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_eef69 thead th.level0 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
#   text-align: left;
# }
# #T_eef69 thead th.level1 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
#   text-align: left;
# }
# #T_eef69 thead th.level2 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
#   text-align: left;
# }
# #T
#T_eef69_row39_col1, #T_eef69_row39_col2, #T_eef69_row39_col3, #T_eef69_row40_col1, #T_eef69_row40_col2, #T_eef69_row40_col3, #T_eef69_row40_col4, #T_eef69_row41_col1, #T_eef69_row41_col2, #T_eef69_row41_col3, #T_eef69_row41_col4, #T_eef69_row42_col1, #T_eef69_row42_col2, #T_eef69_row42_col3, #T_eef69_row42_col4, #T_eef69_row43_col1, #T_eef69_row43_col2, #T_eef69_row43_col3, #T_eef69_row43_col4, #T_eef69_row44_col1, #T_eef69_row44_col3, #T_eef69_row44_col4, #T_eef69_row45_col1, #T_eef69_row45_col2, #T_eef69_row45_col3, #T_eef69_row45_col4, #T_eef69_row46_col1, #T_eef69_row46_col2, #T_eef69_row46_col3, #T_eef69_row46_col4, #T_eef69_row47_col1, #T_eef69_row47_col2, #T_eef69_row47_col3, #T_eef69_row47_col4, #T_eef69_row49_col1, #T_eef69_row49_col2, #T_eef69_row49_col3, #T_eef69_row49_col4, #T_eef69_row50_col1, #T_eef69_row50_col2, #T_eef69_row50_col3, #T_eef69_row50_col4, #T_eef69_row51_col1, #T_eef69_row51_col3, #T_eef69_row51_col4, #T_eef69_row52_col1, #T_eef69_row52_col3, #T_eef69_row52_col4, #T_eef69_row53_col2, #T_eef69_row53_col3, #T_eef69_row54_col1, #T_eef69_row54_col3, #T_eef69_row54_col4, #T_eef69_row55_col1, #T_eef69_row55_col2, #T_eef69_row55_col3, #T_eef69_row55_col4, #T_eef69_row56_col1, #T_eef69_row56_col2, #T_eef69_row56_col3, #T_eef69_row57_col1, #T_eef69_row57_col3, #T_eef69_row58_col1, #T_eef69_row58_col2, #T_eef69_row58_col3, #T_eef69_row58_col4, #T_eef69_row59_col1, #T_eef69_row59_col2, #T_eef69_row59_col3, #T_eef69_row59_col4, #T_eef69_row60 ...

# %%
columns = ['Group']
sub_columns_filters = {
    'Group': []
}
sub_index_filters = {
    'Indep Var': [],
    'Id': []
}
indicators = [
'Total Eco Footprint_log',
]

view = reg.df_view(dataframe, indicators, columns, sub_columns_filters, sub_index_filters, f' {eci_col}', 'Group', 'Id')
dfs_to_export[indicators[0]] = view
print(f'{indicators[0]}')
display(view)
# Out:
# Total Eco Footprint_log
# <style type="text/css">
# #T_1ad48 tbody tr th.level-1 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_1ad48 tbody tr th.level0 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_1ad48 tbody tr th.level1 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_1ad48 tbody tr th.level2 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_1ad48 tbody tr th.level3 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_1ad48 tbody tr th.level4 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_1ad48 tbody tr th.level5 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_1ad48 thead th.level0 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
#   text-align: left;
# }
# #T_1ad48 thead th.level1 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
#   text-align: left;
# }
# #T_1ad48 thead th.level2 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
#   text-align: left;
# }
# #T_1ad48_row0_col0, #T_1ad48_row3_col0, #T_1ad48_row5_col0, #T_1ad48_row9_col0, #T_1ad48_row26_col0, #T_1ad48_row100_col0 {
#   background-color: orangered;
#   font-weight: bold;
# }
# #T_1ad48_row0_col1, #T_1ad48_row4_col1, #T_1ad48_row4_col2, #T_1ad48_row4_col4, #T_1ad48_row5_col2, #T_1ad48_row14_col1 {
#   background-color: red;
#   font-weight: bold;
#   border-left: 2px solid black;
# }
# #T_1ad48_row0_col2, #T_1ad48_row0_col3, #T_1ad48_row1_col3, #T_1ad48_row2_col1, #T_1ad48_row2_col2, #T_1ad48_row2_col3, #T_1ad48_row2_col4, #T_1ad48_row3_col1, #T_1ad48_row3_col3, #T_1ad48_row3_col4, #T_1ad48_row4_col3, #T_1ad48_row5_col1, #T_1ad48_row5_col3, #T_1ad48_row7_col2, #T_1ad48_row7_col3, #T_1ad48_row7_col4, #T_1ad48_row8_col1, #T_1ad48_row8_col2, #T_1ad48_row9_col1, #T_1ad48_row9_col2, #T_1ad48_row9_col3, #T_1ad48_row10_col2, #T_1ad48_row10_col3, #T_1ad48_row11_col1, #T_1ad48_row11_col2, #T_1ad48_row11_col3, #T_1ad48_row11_col4, #T_1ad48_row13_col1, #T_1ad48_row13_col2, #T_1ad48_row13_col3, #T_1ad48_row13_col4, #T_1ad48_row14_col2, #T_1ad48_row14_col4, #T_1ad48_row15_col1, #T_1ad48_row15_col2, #T_1ad48_row15_col3, #T_1ad48_row15_col4, #T_1ad48_row16_col1, #T_1ad48_row16_col2, #T_1ad48_row16_col3, #T_1ad48_row16_col4, #T_1ad48_row17_col2, #T_1ad48_row17_col3, #T_1ad48_row17_col4, #T_1ad48_row18_col1, #T_1ad48_row18_col2, #T_1ad48_row18_col3, #T_1ad48_row19_col2, #T_1ad48_row19_col3, #T_1ad48_row20_col1, #T_1ad48_row20_col2, #T_1ad48_row20_col4, #T_1ad48_row21_col1, #T_1ad48_row21_col2, #T_1ad48_row21_col3, #T_1ad48_row21_col4, #T_1ad48_row22_col1, #T_1ad48_row22_col2, #T_1ad48_row22_col3, #T_1ad48_row22_col4, #T_1ad48_row23_col1, #T_1ad48_row23_col2, #T_1ad48_row23_col3, #T_1ad48_row23_col4, #T_1ad48_row24_col1, #T_1ad48_row24_col4, #T_1ad48_row25_col1, #T_1ad48_row25_col2, #T_1ad48_row25_col3, #T_1ad48_row25_col4, #T_1ad48_row26_col1, #T_1ad48_row26_col2, #T_1ad48_row26_col3, #T_1ad48_row27_col1, #T_1ad48_row27_col3, #T_1ad48_row28_col1, #T_1ad48_row28_col2, #T_1ad48_row28_col3, #T_1ad48_row28_col4, #T_1ad48_row30_col1, #T_1ad48_row30_col2, #T_1ad48_row30_col3, #T_1ad48_row30_col4, #T_1ad48_row31_col1, #T_1ad48_row31_col2, #T_1ad48_row31_col3, #T_1ad48_row31_col4, #T_1ad48_row32_col2, #T_1ad48_row32_col3, #T_1ad48_row32_col4, #T_1ad48_row33_col1, #T_1ad48_row33_col2, #T_1ad48_row33_col3, #T_1ad48_row33_col4, #T_1ad48_row34_col1, #T_1ad48_row34_col2, #T_1ad48_row34_col3, #T_1ad48_row34_col4, #T_1ad48_row35_col2, #T_1ad48_row35_col3, #T_1ad48_row35_col4, #T_1ad48_row36_col1, #T_1ad48_row36_col2, #T_1ad48_row36_col3, #T_1ad48_row36_col4, #T_1ad48_row37_col2, #T_1ad48_row37_col3, #T_1ad48_row38_col1, #T_1ad48_row38_col2, #T_1ad48_row38_col3, #T_1ad48_row38_col4, #T_1ad48_row39_col1, #T_1ad48_row39_col2, #T_1ad48_row39_col3, #T_1ad48_row39_col4, #T_1ad48_row40_col1, #T_1ad48_row40_col2, #T_1ad48_row40_col3, #T_1ad48_row40_col4, #T_1ad48_row41_col1, #T_1ad48_row41_col2, #T_1ad48_row41_col3, #T_1ad48_row41_col4, #T_1ad48_row42_col1, #T_1ad48_row42_col2, #T_1ad48_row42_col4, #T_1ad48_row43_col1, #T_1ad48_row43_col2, #T_1ad48_row43_col3, #T_1ad48_row43_col4, #T_1ad48_row44_col1, #T_1ad48_row44_col2, #T_1ad48_row44_col3, #T_1ad48_row44_col4, #T_1ad48_row45_col1, #T_1ad48_row45_col2, #T_1ad48_row45_col3, #T_1ad48_row45_col4, #T_1ad48_row46_col1, #T_1ad48_row46_col3, #T_1ad48_row46_col4, #T_1ad48_row47_col1, #T_1ad48_row47_col2, #T_1ad48_row47_col3, #T_1ad48_row47_col4, #T_1ad48_row49_col1, #T_1ad48_row49_col2, #T_1ad48_row49_col3, #T_1ad48_row49_col4, #T_1ad48_row50_col1, #T_1ad48_row50_col2, #T_1ad48_row50_col3, #T_1ad48_row50_col4, #T_1ad48_row51_col1, #T_1ad48_row51_col2, #T_1ad48_row51_col3, #T_1ad48_row51_col4, #T_1ad48_row52_col2, #T_1ad48_row52_col3, #T_1ad48_row52_col4, #T_1ad48_row53_col2, #T_1ad48_row53_col3, #T_1ad48_row53_col4, #T_1ad48_row54_col1, #T_1ad48_row54_col2, #T_1ad48_row54_col3, #T_1ad48_row54_col4, #T_1ad48_row55_col2, #T_1ad48_row55_col3, #T_1ad48_row56_col1, #T_1ad48_row56_col2, #T_1ad48_row56_col3, #T_1ad48_row56_col4, #T_1ad48_row57_col1, #T_1ad48_row57_col2, #T_1ad48_row57_col3, #T_1ad48_row57_col4, #T_1ad48_row58_col1, #T_1ad48_row58_col2, #T_1ad48_row58_col3, #T_1ad48_row58_col4, #T_1ad48_row59_col1, #T_1ad48_row59_col2, #T_1ad48_row59_col3, #T_1ad48_row59_col4, #T_1ad48_row60_col1, #T_1ad48_row60_col2, #T_1ad48_row60_col3, #T_1ad48_row60_col4, #T_1ad48_row61_col1, #T_1ad48_row61_col2, #T_1ad48_r ...

# %%
columns = ['Group']
sub_columns_filters = {
    'Group': []
}
sub_index_filters = {
    'Indep Var': [],
    'Id': []
}
indicators = [
'GDP, PPP (current international $)_in_5_years_log',
]

view = reg.df_view(dataframe, indicators, columns, sub_columns_filters, sub_index_filters, f' {eci_col}', 'Group', 'Id')
dfs_to_export[indicators[0]] = view
print(f'{indicators[0]}')
display(view)
# Out:
# CO2 emissions (kt)_log
# <style type="text/css">
# #T_7f3f6 tbody tr th.level-1 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_7f3f6 tbody tr th.level0 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_7f3f6 tbody tr th.level1 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_7f3f6 tbody tr th.level2 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_7f3f6 tbody tr th.level3 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_7f3f6 tbody tr th.level4 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_7f3f6 tbody tr th.level5 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_7f3f6 thead th.level0 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
#   text-align: left;
# }
# #T_7f3f6 thead th.level1 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
#   text-align: left;
# }
# #T_7f3f6 thead th.level2 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
#   text-align: left;
# }
# #T_7f3f6_row0_col1, #T_7f3f6_row0_col4, #T_7f3f6_row4_col1, #T_7f3f6_row4_col2, #T_7f3f6_row4_col4, #T_7f3f6_row5_col2 {
#   background-color: red;
#   font-weight: bold;
#   border-left: 2px solid black;
# }
# #T_7f3f6_row0_col2, #T_7f3f6_row0_col3, #T_7f3f6_row1_col3, #T_7f3f6_row2_col1, #T_7f3f6_row2_col2, #T_7f3f6_row2_col3, #T_7f3f6_row2_col4, #T_7f3f6_row3_col1, #T_7f3f6_row3_col4, #T_7f3f6_row4_col3, #T_7f3f6_row5_col1, #T_7f3f6_row5_col3, #T_7f3f6_row6_col4, #T_7f3f6_row7_col2, #T_7f3f6_row7_col3, #T_7f3f6_row7_col4, #T_7f3f6_row8_col1, #T_7f3f6_row8_col2, #T_7f3f6_row8_col4, #T_7f3f6_row9_col1, #T_7f3f6_row9_col2, #T_7f3f6_row10_col2, #T_7f3f6_row10_col3, #T_7f3f6_row11_col1, #T_7f3f6_row11_col2, #T_7f3f6_row11_col3, #T_7f3f6_row11_col4, #T_7f3f6_row13_col1, #T_7f3f6_row13_col2, #T_7f3f6_row13_col3, #T_7f3f6_row14_col1, #T_7f3f6_row14_col2, #T_7f
_col3, #T_7f3f6_row44_col4, #T_7f3f6_row45_col1, #T_7f3f6_row45_col2, #T_7f3f6_row45_col3, #T_7f3f6_row45_col4, #T_7f3f6_row46_col1, #T_7f3f6_row46_col2, #T_7f3f6_row46_col3, #T_7f3f6_row47_col1, #T_7f3f6_row47_col2, #T_7f3f6_row47_col3, #T_7f3f6_row47_col4, #T_7f3f6_row49_col1, #T_7f3f6_row49_col2, #T_7f3f6_row49_col3, #T_7f3f6_row49_col4, #T_7f3f6_row50_col1, #T_7f3f6_row50_col2, #T_7f3f6_row50_col3, #T_7f3f6_row50_col4, #T_7f3f6_row51_col1, #T_7f3f6_row51_col2, #T_7f3f6_row51_col3, #T_7f3f6_row51_col4, #T_7f3f6_row52_col1, #T_7f3f6_row52_col2, #T_7f3f6_row52_col3, #T_7f3f6_row53_col1, #T_7f3f6_row53_col3, #T_7f3f6_row53_col4, #T_7f3f6_row54_col3, #T_7f3f6_row54_col4, #T_7f3f6_row55_col2, #T_7f3f6_row55_col3, #T_7f3f6_row55_col4, #T_7f3f6_row56_col2, #T_7f3f6_row56_col3, #T_7f3f6_row56_col4, #T_7f3f6_row57_col1, #T_7f3f6_row57_col2, #T_7f3f6_row57_col3, #T_7f3f6_row57_col4, #T_7f3f6_row58_col1, #T_7f3f6_row58_col2, #T_7f3f6_row58_col3, #T_7f3f6_row58_col4, #T_7f3f6_row59_col1, #T_7f3f6_row59_col2, #T_7f3f6_row59_col3, #T_7f3f6_row59_col4, #T_7f3f6_row60_col1, #T_7f3f6_row60_col2, #T_7f3f6_row60_col3, #T_7f3f6_row60_col4, #T_7f3f6_row61_col1, #T_7f3f6_row61_col2, #T_7f3f6_r ...

# %%
columns = ['Group']
sub_columns_filters = {
    'Group': []
}
sub_index_filters = {
    'Indep Var': [],
    'Id': []
}
indicators = [
'GDP, PPP (current international $)_in_3_years_log',
]

view = reg.df_view(dataframe, indicators, columns, sub_columns_filters, sub_index_filters, f' {eci_col}', 'Group', 'Id')
dfs_to_export[indicators[0]] = view
print(f'{indicators[0]}')
display(view)
# Out:
# GDP, PPP (current international $)_in_3_years_log
# <style type="text/css">
# #T_bc150 tbody tr th.level-1 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_bc150 tbody tr th.level0 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_bc150 tbody tr th.level1 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_bc150 tbody tr th.level2 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_bc150 tbody tr th.level3 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_bc150 tbody tr th.level4 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_bc150 tbody tr th.level5 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_bc150 thead th.level0 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
#   text-align: left;
# }
# #T_bc150 thead th.level1 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
#   text-align: left;
# }
# #T_bc150 thead th.level2 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
#   text-align: left;
# }
# #T_bc150_row0_col1, #T_bc150_row2_col3, #T_bc150_row4_col3, #T_bc150_row19_col1, #T_bc150_row24_col1, #T_bc150_row43_col2, #T_bc150_row51_col4, #T_bc150_row55_col4, #T_bc150_row56_col4, #T_bc150_row61_col1, #T_bc150_row69_col4, #T_bc150_row74_col1, #T_bc150_row74_col4, #T_bc150_row80_col1, #T_bc150_row84_col3, #T_bc150_row92_col4, #T_bc150_row93_col1, #T_bc150_row93_col4, #T_bc150_row103_col2, #T_bc150_row111_col4, #T_bc150_row116_col1, #T_bc150_row127_col3 {
#   background-color: orangered;
#   font-weight: bold;
#   border-left: 2px solid black;
# }
# #T_bc150_row0_col2, #T_bc150_row0_col3, #T_bc150_row2_col1, #T_bc150_row2_col2, #T_bc150_row2_col4, #T_bc150_row3_col1, #T_bc150_row3_col2, #T_bc150_row3_col3, #T_bc150_row3_col4, #T_bc150_row5_col1, #T_bc150_row5_col3, #T_bc150_row7_col1, #T_bc150_row7_col3, #T_bc150_row8_col1, #T_bc150_row8_col2, #T_bc150_row8_col4, #T_bc150_row9_col1, #T_bc150_row9_col2, #T_bc150_row10_col2, #T_bc150_row10_col3, #T_bc150_row10_col4, #T_bc150_row11_col1, #T_bc150_row11_col2, #T_bc150_row11_col3, #T_bc150_row11_col4, #T_bc150_row13_col1, #T_bc150_row13_col2, #T_bc150_row13_col3, #T_bc150_row14_col1, #T_bc150_row14_col2, #T_bc150_row15_col1, #T_bc150_row15_col2, #T_bc150_row15_col3, #T_bc150_row15_col4, #T_bc150_row16_col1, #T_bc150_row16_col2, #T_bc150_row16_col3, #T_bc150_row16_col4, #T_bc150_row17_col1, #T_bc150_row17_col2, #T_bc150_row17_col3, #T_bc150_row17_col4, #T_bc150_row18_col1, #T_bc150_row18_col3, #T_bc150_row19_col2, #T_bc150_row19_col3, #T_bc150_row19_col4, #T_bc150_row20_col2, #T_bc150_row20_col3, #T_bc150_row21_col1, #T_bc150_row22_col1, #T_bc150_row22_col2, #T_bc150_row22_col3, #T_bc150_row22_col4, #T_bc150_row23_col1, #T_bc150_row23_col2, #T_bc150_row23_col3, #T_bc150_row23_col4, #T_bc150_row24_col2, #T_bc150_row24_col3, #T_bc150_row24_col4, #T_bc150_row25_col1, #T_bc150_row25_col2, #T_bc150_row25_col3, #T_bc150_row25_col4, #T_bc150_row26_col2, #T_bc150_row26_col3, #T_bc150_row26_col4, #T_bc150_row27_col1, #T_bc150_row27_col2, #T_bc150_row27_col4, #T_bc150_row28_col1, #T_bc150_row28_col2, #T_bc150_row28_col3, #T_bc150_row28_col4, #T_bc150_row30_col1, #T_bc150_row30_col2, #T_bc150_row30_col3, #T_bc150_row30_col4, #T_bc150_row31_col1, #T_bc150_row31_col2, #T_bc150_row31_col3, #T_bc150_row31_col4, #T_bc150_row32_col1, #T_bc150_row32_col3, #T_bc150_row32_col4, #T_bc150_row33_col1, #T_bc150_row33_col2, #T_bc150_row33_col4, #T_bc150_row34_col1, #T_bc150_row34_col2, #T_bc150_row34_col3, #T_bc150_row34_col4, #T_bc150_row35_col1, #T_bc150_row35_col2, #T_bc150_row35_col4, #T_bc150_row36_col1, #T_bc150_row36_col2, #T_bc150_row36_col3, #T_bc150_row36_col4, #T_bc150_row37_col1, #T_bc150_row37_col2, #T_bc150_row37_col3, #T_bc150_row37_col4, #T_bc150_row38_col1, #T_bc150_row38_col3, #T_bc150_row39_col1, #T_bc150_row39_col2, #T_bc150_row39_col3, #T_bc150_row39_col4, #T_bc150_row40_col1, #T_bc150_row40_col2, #T_bc150_row40_col3, #T_bc150_row40_col4, #T_bc150_row41_col1, #T_bc150_row41_col2, #T_bc150_row41_col3, #T_bc150_row41_col4, #T_bc150_row42_col1, #T_bc150_row42_col2, #T_bc150_row42_col3, #T_bc150_row42_col4, #T_bc150_row43_col3, #T_bc150_row44_col1, #T_bc150_row44_col2, #T_bc150_row44_col3, #T_bc150_row44_col4, #T_bc150_row45_col2, #T_bc150_row46_col1, #T_bc150_row46_col2, #T_bc150_row46_col3, #T_bc150_row46_col4, #T_bc150_row47_col1, #T_bc150_row47_col2, #T_bc150_row47_col3, #T_bc150_row47_col4, #T_bc150_row49_col1, #T_bc150_row49_col2, #T_bc150_row49_col3, #T_bc150_row49_col4, #T_bc150_row50_col1, #T_bc150_row50_col2, #T_bc150_row50_col3, #T_bc150_row51_col1, #T_bc150_row52_col1, #T_bc150_row52_col2, #T_bc150_row52_col3, #T_bc150_row52_col4, #T_bc150_row53_col1, #T_bc150_row53_col2, #T_bc150_row53_col3, #T_bc150_row53_col4, #T_bc150_row54_col1, #T_bc150_row54_col2, #T_bc150_row54_col3, #T_bc150_row54_col4, #T_bc150_row55_col1, #T_bc150_row55_col2, #T_bc150_row55_col3, #T_bc150_row56_col2, #T_bc150_row56_col3, #T_bc150_row57_col2, #T_bc150_row57_col3, #T_bc150_row57_col4, #T_bc150_row58_col1, #T_bc150_row59_col1, #T_bc150_row59_col2, #T_bc150_row59_col3, #T_bc150_row59_col4, #T_bc150_row60_col1, #T_bc150_row60_col2, #T_bc150_row60_col3, #T_bc150_row60_col4, #T_bc150_row61_col2, #T_bc150_row61_col3, #T_bc150_row61_col4, #T_bc150_row62_col1, #T_bc150_row62_col2, #T_bc150_row62_col3, #T_bc150_row62_col4, #T_bc150_row63_col2, #T_bc150_row63_col3, #T_bc150_row63_col4, #T_bc150_row64_col1, #T_bc150_row64_col2, #T_bc150_row64_col3, #T_bc150_row64_col4, #T_bc150_row65_col1, #T_bc150_row65_col2, #T_bc150_row65_col4, #T_bc150_row66_col1, #T_bc15 ...

# %%
columns = ['Group']
sub_columns_filters = {
    'Group': []
}
sub_index_filters = {
    'Indep Var': [],
    'Id': []
}
indicators = [
'GDP, PPP (current international $)_log',
]

view = reg.df_view(dataframe, indicators, columns, sub_columns_filters, sub_index_filters, f' {eci_col}', 'Group', 'Id')
dfs_to_export[indicators[0]] = view
print(f'{indicators[0]}')
display(view)
# Out:
# GDP, PPP (current international $)_log
# <style type="text/css">
# #T_d39cf tbody tr th.level-1 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_d39cf tbody tr th.level0 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_d39cf tbody tr th.level1 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_d39cf tbody tr th.level2 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_d39cf tbody tr th.level3 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_d39cf tbody tr th.level4 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_d39cf tbody tr th.level5 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_d39cf thead th.level0 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
#   text-align: left;
# }
# #T_d39cf thead th.level1 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
#   text-align: left;
# }
# #T_d39cf thead th.level2 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
#   text-align: left;
# }
# #T_d39cf_row0_col1, #T_d39cf_row0_col4, #T_d39cf_row4_col1, #T_d39cf_row4_col2, #T_d39cf_row4_col3, #T_d39cf_row4_col4, #T_d39cf_row5_col2, #T_d39cf_row5_col4, #T_d39cf_row9_col3, #T_d39cf_row9_col4, #T_d39cf_row14_col3, #T_d39cf_row14_col4, #T_d39cf_row18_col2, #T_d39cf_row18_col4, #T_d39cf_row27_col3, #T_d39cf_row32_col4, #T_d39cf_row36_col2, #T_d39cf_row36_col4, #T_d39cf_row69_col3, #T_d39cf_row69_col4, #T_d39cf_row73_col4, #T_d39cf_row90_col3, #T_d39cf_row92_col2, #T_d39cf_row92_col4, #T_d39cf_row111_col3, #T_d39cf_row111_col4, #T_d39cf_row115_col4 {
#   background-color: red;
#   font-weight: bold;
#   border-left: 2px solid black;
# }
# #T_d39cf_row0_col2, #T_d39cf_row0_col3, #T_d39cf_row2_col1, #T_d39cf_row2_col2, #T_d39cf_row2_col4, #T_d39cf_row3_col1, #T_d39cf_row3_col2, #T_d39cf_row3_col3, #T_d39cf_row3_col4, #T_d39cf_row5_col3, #T_d39cf_row7_col1, #T_d39cf_row7_col2, #T_d39cf_row7_col3, #T_d39cf_row8_col1, #T_d39cf_row8_col2, #T_d39cf_row8_col4, #T_d39cf_row9_col1, #T_d39cf_row9_col2, #T_d39cf_row10_col2, #T_d39cf_row10_col3, #T_d39cf_row10_col4, #T_d39cf_row11_col1, #T_d39cf_row11_col2, #T_d39cf_row11_col3, #T_d39cf_row11_col4, #T_d39cf_row13_col1, #T_d39cf_row13_col2, #T_d39cf_row13_col3, #T_d39cf_row13_col4, #T_d39cf_row14_col1, #T_d39cf_row15_col1, #T_d39cf_row15_col2, #T_d39cf_row15_col3, #T_d39cf_row15_col4, #T_d39cf_row16_col1, #T_d39cf_row16_col2, #T_d39cf_row16_col3, #T_d39cf_row16_col4, #T_d39cf_row17_col1, #T_d39cf_row17_col2, #T_d39cf_row18_col1, #T_d39cf_row19_col2, #T_d39cf_row19_col3, #T_d39cf_row19_col4, #T_d39cf_row20_col3, #T_d39cf_row21_col1, #T_d39cf_row21_col2, #T_d39cf_row21_col3, #T_d39cf_row21_col4, #T_d39cf_row22_col1, #T_d39cf_row22_col2, #T_d39cf_row22_col3, #T_d39cf_row22_col4, #T_d39cf_row23_col1, #T_d39cf_row23_col2, #T_d39cf_row23_col3, #T_d39cf_row23_col4, #T_d39cf_row24_col1, #T_d39cf_row24_col2, #T_d39cf_row24_col3, #T_d39cf_row24_col4, #T_d39cf_row25_col1, #T_d39cf_row25_col2, #T_d39cf_row25_col3, #T_d39cf_row25_col4, #T_d39cf_row26_col2, #T_d39cf_row26_col3, #T_d39cf_row26_col4, #T_d39cf_row27_col1, #T_d39cf_row27_col2, #T_d39cf_row27_col4, #T_d39cf_row28_col1, #T_d39cf_row28_col2, #T_d39cf_row28_col3, #T_d39cf_row28_col4, #T_d39cf_row30_col1, #T_d39cf_row30_col2, #T_d39cf_row30_col3, #T_d39cf_row30_col4, #T_d39cf_row31_col1, #T_d39cf_row31_col2, #T_d39cf_row31_col3, #T_d39cf_row31_col4, #T_d39cf_row32_col1, #T_d39cf_row33_col1, #T_d39cf_row33_col2, #T_d39cf_row33_col3, #T_d39cf_row33_col4, #T_d39cf_row34_col1, #T_d39cf_row34_col2, #T_d39cf_row34_col3, #T_d39cf_row34_col4, #T_d39cf_row35_col1, #T_d39cf_row35_col2, #T_d39cf_row35_col3, #T_d39cf_row35_col4, #T_d39cf_row36_col1, #T_d39cf_row37_col2, #T_d39cf_row37_col3, #T_d39cf_row37_col4, #T_d39cf_row38_col2, #T_d39cf_row38_col3, #T_d39cf_row39_col1, #T_d39cf_row39_col2, #T_d39cf_row39_col3, #T_d39cf_row39_col4, #T_d39cf_row40_col1, #T_d39cf_row40_col2, #T_d39cf_row40_col3, #T_d39cf_row40_col4, #T_d39cf_row41_col1, #T_d39cf_row41_col2, #T_d39cf_row41_col3, #T_d39cf_row41_col4, #T_d39cf_row42_col1, #T_d39cf_row42_col2, #T_d39cf_row42_col3, #T_d39cf_row42_col4, #T_d39cf_row43_col1, #T_d39cf_row43_col2, #T_d39cf_row43_col3, #T_d39cf_row43_col4, #T_d39cf_row44_col1, #T_d39cf_row44_col2, #T_d39cf_row44_col3, #T_d39cf_row44_col4, #T_d39cf_row45_col1, #T_d39cf_row45_col2, #T_d39cf_row45_col3, #T_d39cf_row45_col4, #T_d39cf_row46_col1, #T_d39cf_row46_col2, #T_d39cf_row46_col4, #T_d39cf_row47_col1, #T_d39cf_row47_col2, #T_d39cf_row47_col3, #T_d39cf_row47_col4, #T_d39cf_row49_col1, #T_d39cf_row49_col2, #T_d39cf_row49_col3, #T_d39cf_row49_col4, #T_d39cf_row50_col1, #T_d39cf_row50_col2, #T_d39cf_row50_col3, #T_d39cf_row50_col4, #T_d39cf_row51_col1, #T_d39cf_row51_col2, #T_d39cf_row51_col3, #T_d39cf_row51_col4, #T_d39cf_row52_col1, #T_d39cf_row52_col3, #T_d39cf_row52_col4, #T_d39cf_row53_col1, #T_d39cf_row53_col2, #T_d39cf_row53_col3, #T_d39cf_row53_col4, #T_d39cf_row54_col1, #T_d39cf_row54_col2, #T_d39cf_row54_col3, #T_d39cf_row54_col4, #T_d39cf_row55_col1, #T_d39cf_row55_col3, #T_d39cf_row56_col2, #T_d39cf_row56_col3, #T_d39cf_row56_col4, #T_d39cf_row57_col2, #T_d39cf_row57_col3, #T_d39cf_row57_col4, #T_d39cf_row58_col1, #T_d39cf_row58_col2, #T_d39cf_row58_col3, #T_d39cf_row58_col4, #T_d39cf_row59_col1, #T_d39cf_row59_col2, #T_d39cf_row59_col3, #T_d39cf_row59_col4, #T_d39cf_row60_col1, #T_d39cf_row60_col2, #T_d39cf_row60_col3, #T_d39cf_row60_col4, #T_d39cf_row61_col1, #T_d39cf_row61_col2, #T_d39cf_row61_col3, #T_d39cf_row61_col4, #T_d39cf_row62_col1, #T_d39cf_row62_col2, #T_d39cf_row62_col3, #T_d39cf_row62_col4, #T_d39cf_row63_col1, #T_d39cf_row63_col2, #T_d39cf_row63_col3, #T_d39c ...

# %%
columns = ['Group']
sub_columns_filters = {
    'Group': []
}
sub_index_filters = {
    'Indep Var': [],
    'Id': []
}
indicators = [
'GDP growth (annual %)_in_5_years',
]

view = reg.df_view(dataframe, indicators, columns, sub_columns_filters, sub_index_filters, f' {eci_col}', 'Group', 'Id')
dfs_to_export[indicators[0]] = view
print(f'{indicators[0]}')
display(view)
# Out:
# GDP growth (annual %)_in_5_years
# <style type="text/css">
# #T_08dbe tbody tr th.level-1 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_08dbe tbody tr th.level0 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_08dbe tbody tr th.level1 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_08dbe tbody tr th.level2 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_08dbe tbody tr th.level3 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_08dbe tbody tr th.level4 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_08dbe tbody tr th.level5 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_08dbe thead th.level0 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
#   text-align: left;
# }
# #T_08dbe thead th.level1 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
#   text-align: left;
# }
# #T_08dbe thead th.level2 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
#   text-align: left;
# }
# #T_08dbe_row0_col1, #T_08dbe_row0_col2, #T_08dbe_row0_col3, #T_08dbe_row0_col4, #T_08dbe_row1_col2, #T_08dbe_row1_col3, #T_08dbe_row2_col1, #T_08dbe_row2_col2, #T_08dbe_row2_col3, #T_08dbe_row2_col4, #T_08dbe_row3_col1, #T_08dbe_row3_col2, #T_08dbe_row3_col3, #T_08dbe_row3_col4, #T_08dbe_row4_col1, #T_08dbe_row4_col3, #T_08dbe_row5_col1, #T_08dbe_row5_col2, #T_08dbe_row5_col4, #T_08dbe_row6_col1, #T_08dbe_row6_col2, #T_08dbe_row6_col3, #T_08dbe_row6_col4, #T_08dbe_row7_col1, #T_08dbe_row7_col2, #T_08dbe_row7_col3, #T_08dbe_row7_col4, #T_08dbe_row8_col1, #T_08dbe_row8_col2, #T_08dbe_row8_col4, #T_08dbe_row9_col1, #T_08dbe_row9_col2, #T_08dbe_row9_col4, #T_08dbe_row10_col1, #T_08dbe_row10_col2, #T_08dbe_row10_col3, #T_08dbe_row10_col4, #T_08dbe_row11_col1, #T_08dbe_row11_col2, #T_08dbe_row11_col3, #T_08dbe_row11_col4, #T_08dbe_row13_col2, #T_08dbe_row13_col3, #T_08dbe_row13_col4, #T_08dbe_row14_col1, #T_08dbe_row14_col2, #T_08dbe_row14_col4, #T_08dbe_row15_col1, #T_08d
T_08dbe_row47_col2, #T_08dbe_row47_col3, #T_08dbe_row47_col4, #T_08dbe_row48_col1, #T_08dbe_row48_col2, #T_08dbe_row48_col3, #T_08dbe_row48_col4, #T_08dbe_row49_col1, #T_08dbe_row49_col2, #T_08dbe_row49_col3, #T_08dbe_row49_col4, #T_08dbe_row50_col1, #T_08dbe_row50_col2, #T_08dbe_row50_col4, #T_08dbe_row51_col2, #T_08dbe_row51_col3, #T_08dbe_row52_col1, #T_08dbe_row52_col2, #T_08dbe_row52_col3, #T_08dbe_row52_col4, #T_08dbe_row53_col1, #T_08dbe_row53_col2, #T_08dbe_row53_col4, #T_08dbe_row54_col1, #T_08dbe_row54_col2, #T_08dbe_row54_col3, #T_08dbe_row55_col1, #T_08dbe_row55_col2, #T_08dbe_row55_col4, #T_08dbe_row56_col1, #T_08dbe_row56_col2, #T_08dbe_row56_col3, #T_08dbe_row56_col4, #T_08dbe_row57_col1, # ...

# %%
columns = ['Group']
sub_columns_filters = {
    'Group': []
}
sub_index_filters = {
    'Indep Var': [],
    'Id': []
}
indicators = [
'GDP (current US$)_log',
]

view = reg.df_view(dataframe, indicators, columns, sub_columns_filters, sub_index_filters, f' {eci_col}', 'Group', 'Id')
dfs_to_export[indicators[0]] = view
print(f'{indicators[0]}')
display(view)
# Out:
# GDP (current US$)_log
# <style type="text/css">
# #T_93103 tbody tr th.level-1 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_93103 tbody tr th.level0 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_93103 tbody tr th.level1 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_93103 tbody tr th.level2 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_93103 tbody tr th.level3 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_93103 tbody tr th.level4 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_93103 tbody tr th.level5 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
# }
# #T_93103 thead th.level0 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
#   text-align: left;
# }
# #T_93103 thead th.level1 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
#   text-align: left;
# }
# #T_93103 thead th.level2 {
#   border-top: 2px solid black;
#   border-right: 2px solid black;
#   border-left: 2px solid black;
#   border-bottom: 2px solid black;
#   text-align: left;
# }
# #T_93103_row0_col1, #T_93103_row0_col4, #T_93103_row4_col1, #T_93103_row4_col2, #T_93103_row4_col3, #T_93103_row4_col4, #T_93103_row5_col2, #T_93103_row5_col4, #T_93103_row9_col3, #T_93103_row9_col4, #T_93103_row103_col4 {
#   background-color: red;
#   font-weight: bold;
#   border-left: 2px solid black;
# }
# #T_93103_row0_col2, #T_93103_row0_col3, #T_93103_row2_col1, #T_93103_row2_col2, #T_93103_row2_col4, #T_93103_row3_col1, #T_93103_row3_col2, #T_93103_row3_col3, #T_93103_row3_col4, #T_93103_row5_col3, #T_93103_row6_col1, #T_93103_row7_col1, #T_93103_row7_col2, #T_93103_row7_col3, #T_93103_row8_col1, #T_93103_row8_col2, #T_93103_row8_col4, #T_93103_row9_col1, #T_93103_row9_col2, #T_93103_row10_col2, #T_93103_row10_col3, #T_93103_row11_col1, #T_93103_row11_col2, #T_93103_row11_col3, #T_93103_row11_col4, #T_93103_row13_col1, #T_93103_row13_col2, #T_93103_row13_col3, #T_93103_row13_col4, #T_93103_row14_col1, #T_93103_row14_col2, #T_93103_row14_col3, #T_93103_row14_col4, #T_93103_row15_col1, #T_93103_row15_col2, #T_93103_row15_col3, #T_93103_row15_col4, #T_93103_row16_col1, #T_93103_row16_col2, #T_93103_row16_col3, #T_93103_row16_col4, #T_93103_row17_col1, #T_93103_row17_col2, #T_93103_row17_col3, #T_93103_row17_col4, #T_93103_row18_col1, #T_93103_row18_col2, #T_
93103_row54_col4, #T_93103_row55_col1, #T_93103_row55_col2, #T_93103_row55_col3, #T_93103_row55_col4, #T_93103_row56_col1, #T_93103_row56_col2, #T_93103_row56_col3, #T_93103_row56_col4, #T_93103_row57_col1, #T_93103_row57_col2, #T_93103_row57_col3, #T_93103_row57_col4, #T_93103_row58_col1, #T_93103_row58_col2, #T_93103_row58_col3, #T_93103 ...

# %%
remap_names = {
    'GDP growth (annual %)_in_5_years': 'GDPgrowth(annual%)in5years',
    'Total greenhouse gas emissions (kt of CO2 equivalent)_log': 'Total GHG (ktCO2eq)_log',
    'GNI, PPP (current international $)_log': 'GNI,PPP (curr int$)_log',
    'GDP, PPP (current international $)_in_5_years_log': 'GDP,PPP (curr int$)in5years_log',
    'GDP, PPP (current international $)_in_3_years_log': 'GDP,PPP (curr int$)in3years_log',
    'GDP, PPP (current international $)_log': 'GDP,PPP (curr int$)_log',
    'CO2 emissions (metric tons per capita)_log': 'CO2emissions (mtons percap)_log',
    'CO2 emissions (kg per PPP $ of GDP)_log': 'CO2emissions (kgpPPP$ofGDP)_log',

}
var_names = [remap_names.get(v, v) for v in dfs_to_export.keys()]

# %%
excel_path = DB_PATH / f"{eci_col}_Fixed_Entity_Panel_OLS_Fixed_Entity_Effects_Regressions_.xlsx"
reg.save_dfs_to_excel(dfs_to_export.values(), var_names, excel_path)
book = openpyxl.load_workbook(excel_path)
for sheet_name in book.sheetnames:
    sheet = book[sheet_name]
    auto_adjust_columns_width(sheet)
book.save(excel_path)

# %% [markdown]
# ***

# %%
dfs_to_export = {'All variations': view}
sheet_names = ['Low income', 'Lower middle income', 'Upper middle income', 'High income', 'All countries', 'All variations']

for income in dataframe.index.get_level_values('Income').unique():
    sub_columns_filters['Income'] = [income]
    income_view = reg.df_view(dataframe, indicators, columns, sub_columns_filters, sub_index_filters, 'Income', 'Indep Var')
    dfs_to_export[income] = income_view
    
dfs_to_export = [dfs_to_export[n] for n in sheet_names]
reg.save_dfs_to_excel(dfs_to_export, sheet_names, DB_PATH / f"XTREG_{indicators[0]}_Results.xlsx")

# %% [markdown]
# ## Ln Energy Productivity

# %%
columns = ['Income', 'Lag']
sub_columns_filters = {
    'Lag': [],
    'Income': []
}
sub_index_filters = {
    'Indep Var': ['ECI', 'Agriculture ECI', 'Fishing ECI', 'Food & Beverages ECI',
       'Machinery ECI', 'Metal Products ECI', 'Mining & Quarrying ECI',
       'Other Manufacturing ECI', 'Petroleum, Chemicals & Non-Metals ECI',
       'Textiles & Wearing Apparel ECI', 'Transport Equipment ECI',
       'Wood & Paper ECI']
}
indicators = [
'Energy Productivity_log',
]

view = reg.df_view(dataframe, indicators, columns, sub_columns_filters, sub_index_filters, 'Income', 'Indep Var')
display(view)

# %%
dfs_to_export = {'All variations': view}
sheet_names = ['Low income', 'Lower middle income', 'Upper middle income', 'High income', 'All countries', 'All variations']

for income in dataframe.index.get_level_values('Income').unique():
    sub_columns_filters['Income'] = [income]
    income_view = reg.df_view(dataframe, indicators, columns, sub_columns_filters, sub_index_filters, 'Income', 'Indep Var')
    dfs_to_export[income] = income_view
    
dfs_to_export = [dfs_to_export[n] for n in sheet_names]
reg.save_dfs_to_excel(dfs_to_export, sheet_names, DB_PATH / f"CS-ARDL_{indicators[0]}_Results.xlsx")

# %% [markdown]
# ## Ecological Footprint

# %%
columns = ['Income', 'Lag']
sub_columns_filters = {
    'Lag': [],
    'Income': []
}
sub_index_filters = {
    'Indep Var': ['ECI', 'Agriculture ECI', 'Fishing ECI', 'Food & Beverages ECI',
       'Machinery ECI', 'Metal Products ECI', 'Mining & Quarrying ECI',
       'Other Manufacturing ECI', 'Petroleum, Chemicals & Non-Metals ECI',
       'Textiles & Wearing Apparel ECI', 'Transport Equipment ECI',
       'Wood & Paper ECI']
}
indicators = [
'Total Eco Footprint',
]

view = reg.df_view(dataframe, indicators, columns, sub_columns_filters, sub_index_filters, 'Income', 'Indep Var')
display(view)

# %%
dfs_to_export = {'All variations': view}
sheet_names = ['Low income', 'Lower middle income', 'Upper middle income', 'High income', 'All countries', 'All variations']

for income in dataframe.index.get_level_values('Income').unique():
    sub_columns_filters['Income'] = [income]
    income_view = reg.df_view(dataframe, indicators, columns, sub_columns_filters, sub_index_filters, 'Income', 'Indep Var')
    dfs_to_export[income] = income_view
    
dfs_to_export = [dfs_to_export[n] for n in sheet_names]
reg.save_dfs_to_excel(dfs_to_export, sheet_names, DB_PATH / f"CS-ARDL_{indicators[0]}_Results.xlsx")

# %% [markdown]
# ## GHG Emissions

# %%
columns = ['Income', 'Lag']
sub_columns_filters = {
    'Lag': [],
    'Income': []
}
sub_index_filters = {
    'Indep Var': ['ECI', 'Agriculture ECI', 'Fishing ECI', 'Food & Beverages ECI',
       'Machinery ECI', 'Metal Products ECI', 'Mining & Quarrying ECI',
       'Other Manufacturing ECI', 'Petroleum, Chemicals & Non-Metals ECI',
       'Textiles & Wearing Apparel ECI', 'Transport Equipment ECI',
       'Wood & Paper ECI']
}
indicators = [
'Total greenhouse gas emissions (kt of CO2 equivalent)_log',
]

view = reg.df_view(dataframe, indicators, columns, sub_columns_filters, sub_index_filters, 'Income', 'Indep Var')
display(view)

# %%
dfs_to_export = {'All variations': view}
sheet_names = ['Low income', 'Lower middle income', 'Upper middle income', 'High income', 'All countries', 'All variations']

for income in dataframe.index.get_level_values('Income').unique():
    sub_columns_filters['Income'] = [income]
    income_view = reg.df_view(dataframe, indicators, columns, sub_columns_filters, sub_index_filters, 'Income', 'Indep Var')
    dfs_to_export[income] = income_view
    
dfs_to_export = [dfs_to_export[n] for n in sheet_names]
reg.save_dfs_to_excel(dfs_to_export, sheet_names, DB_PATH / f"CS-ARDL_{indicators[0]}_Results.xlsx")

# %% [markdown]
# ## GDP

# %%
columns = ['Income', 'Lag']
sub_columns_filters = {
    'Lag': [],
    'Income': []
}
sub_index_filters = {
    'Indep Var': ['ECI', 'Agriculture ECI', 'Fishing ECI', 'Food & Beverages ECI',
       'Machinery ECI', 'Metal Products ECI', 'Mining & Quarrying ECI',
       'Other Manufacturing ECI', 'Petroleum, Chemicals & Non-Metals ECI',
       'Textiles & Wearing Apparel ECI', 'Transport Equipment ECI',
       'Wood & Paper ECI']
}
indicators = [
'GDP per capita (current US$)_log',
]

view = reg.df_view(dataframe, indicators, columns, sub_columns_filters, sub_index_filters, 'Income', 'Indep Var')
display(view)

# %%
dfs_to_export = {'All variations': view}
sheet_names = ['Low income', 'Lower middle income', 'Upper middle income', 'High income', 'All countries', 'All variations']

for income in dataframe.index.get_level_values('Income').unique():
    sub_columns_filters['Income'] = [income]
    income_view = reg.df_view(dataframe, indicators, columns, sub_columns_filters, sub_index_filters, 'Income', 'Indep Var')
    dfs_to_export[income] = income_view
    
dfs_to_export = [dfs_to_export[n] for n in sheet_names]
reg.save_dfs_to_excel(dfs_to_export, sheet_names, DB_PATH / f"CS-ARDL_{indicators[0]}_Results.xlsx")

# %% [markdown]
# ## GDP Growth

# %%
columns = ['Income', 'Lag']
sub_columns_filters = {
    'Lag': [],
    'Income': []
}
sub_index_filters = {
    'Indep Var': ['ECI', 'Agriculture ECI', 'Fishing ECI', 'Food & Beverages ECI',
       'Machinery ECI', 'Metal Products ECI', 'Mining & Quarrying ECI',
       'Other Manufacturing ECI', 'Petroleum, Chemicals & Non-Metals ECI',
       'Textiles & Wearing Apparel ECI', 'Transport Equipment ECI',
       'Wood & Paper ECI']
}
indicators = [
'GDP per capita, PPP (current international $)_in_1_years_log',
]

view = reg.df_view(dataframe, indicators, columns, sub_columns_filters, sub_index_filters, 'Income', 'Indep Var')
display(view)

# %%
dfs_to_export = {'All variations': view}
sheet_names = ['Low income', 'Lower middle income', 'Upper middle income', 'High income', 'All countries', 'All variations']

for income in dataframe.index.get_level_values('Income').unique():
    sub_columns_filters['Income'] = [income]
    income_view = reg.df_view(dataframe, indicators, columns, sub_columns_filters, sub_index_filters, 'Income', 'Indep Var')
    dfs_to_export[income] = income_view
    
dfs_to_export = [dfs_to_export[n] for n in sheet_names]
reg.save_dfs_to_excel(dfs_to_export, sheet_names, DB_PATH / f"CS-ARDL_{indicators[0]}_Results.xlsx")

# %% [markdown]
# ## Energy Intensity

# %%
columns = ['Income', 'Lag']
sub_columns_filters = {
    'Lag': [],
    'Income': []
}
sub_index_filters = {
    'Indep Var': ['ECI', 'Agriculture ECI', 'Fishing ECI', 'Food & Beverages ECI',
       'Machinery ECI', 'Metal Products ECI', 'Mining & Quarrying ECI',
       'Other Manufacturing ECI', 'Petroleum, Chemicals & Non-Metals ECI',
       'Textiles & Wearing Apparel ECI', 'Transport Equipment ECI',
       'Wood & Paper ECI']
}
indicators = [
'Energy Intensity_in_1_years',
]

view = reg.df_view(dataframe, indicators, columns, sub_columns_filters, sub_index_filters, 'Income', 'Indep Var')
display(view)

# %% [markdown]
# ***
